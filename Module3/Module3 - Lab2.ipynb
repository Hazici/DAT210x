# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Load up the wheat seeds dataset into a dataframe. We've stored a copy in the Datasets directory.

# %%
df = pd.read_csv('./Datasets/wheat.data', index_col=0)
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %% [markdown]
# Create a 2d scatter plot that graphs the `area` and `perimeter` features:

# %%
# Plot
plt.scatter(df.area, df.perimeter, c='red', alpha=0.5)
plt.title('area and perimeter')
plt.xlabel('area')
plt.ylabel('perimeter')
plt.show()

# %% [markdown]
# Create a 2d scatter plot that graphs the `groove` and `asymmetry` features:

# %%
plt.scatter(df.groove, df.asymmetry, c='red', alpha=0.5)
plt.title('groove and asymmetry')
plt.xlabel('groove')
plt.ylabel('asymmetry')
plt.show()

# %% [markdown]
# Create a 2d scatter plot that graphs the `compactness` and `width` features:

# %%
plt.scatter(df.compactness, df.width, c='red', alpha=0.5, marker='^')
plt.title('compactness and width')
plt.xlabel('compactness')
plt.ylabel('width')
plt.show()

# %% [markdown]
# ### BONUS
#
# After completing the above, go ahead and run your program Check out the results, and see what happens when you add in the optional display parameter marker with values of either `'^'`, `'.'`, or `'o'`:

# %%
# .. your code here ..

# %%
# Display the graphs:
plt.show()
